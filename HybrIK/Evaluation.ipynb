# %% [markdown]
# ## This is augmentation based case from r720-1

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/model_125.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/model_125.pth...
# loading annotations into memory...
# Done (t=8.38s)
# creating index...
# index created!
# ##### Testing on 3DPW #####
# ...
#   0%|                                                   | 0/101 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 48.350141 | MPJPE: 77.105989, x: 28.768456, y: 33.93, z: 50.594169
#
# Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# XYZ_24 PA-MPJPE: 53.202642 | MPJPE: 75.372728, x: 26.438132, y: 33.85, z: 50.331552
#
# ...
#  11%|████▌                                     | 11/101 [00:44<02:47,  1.86s/it]PVE: 93.01204614930873
# ##### gt 3dpw err: {'MPJPE': 77.10598918289446, 'PA-MPJPE': 48.35014068955008} #####
# ##### Testing on Human3.6M #####
# ...

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_81_89.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_81_89.pth...
# loading annotations into memory...
# Done (t=8.28s)
# creating index...
# index created!
# ##### Testing on 3DPW #####
# ...
#   0%|                                                   | 0/101 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 48.118118 | MPJPE: 78.173273, x: 29.488949, y: 34.00, z: 51.420261
#
# Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# XYZ_24 PA-MPJPE: 52.888234 | MPJPE: 76.122113, x: 27.057395, y: 33.82, z: 50.801096
#
#   9%|███▊                                       | 9/101 [00:43<04:29,  2.93s/it]Test result is saved at exp/test_3d_kpt.json
# PVE: 93.64633010231334
# ##### gt 3dpw err: {'MPJPE': 78.17327255767873, 'PA-MPJPE': 48.11811834329006} #####
# ##### Testing on Human3.6M #####
# ...

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_101_131.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_101_131.pth...
# loading annotations into memory...
# Done (t=8.14s)
# creating index...
# index created!
# ##### Testing on 3DPW #####
# ...
#   0%|                                                   | 0/101 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 47.855797 | MPJPE: 77.265436, x: 28.875073, y: 33.51, z: 51.070333
#
# Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# XYZ_24 PA-MPJPE: 52.645975 | MPJPE: 75.313536, x: 26.691065, y: 33.41, z: 50.417585
#
#   7%|██▉                                        | 7/101 [00:43<08:13,  5.25s/it]Test result is saved at exp/test_3d_kpt.json
# PVE: 92.70445568312844
# ##### gt 3dpw err: {'MPJPE': 77.26543589896994, 'PA-MPJPE': 47.85579718633313} #####
# ##### Testing on Human3.6M #####
# ...

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_121_145.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_121_145.pth...
# loading annotations into memory...
# Done (t=8.41s)
# creating index...
# index created!
# ...
#   0%|                                                    | 0/12 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 47.675427 | MPJPE: 76.627707, x: 28.748056, y: 33.29, z: 50.509625
#
#  33%|██████████████▋                             | 4/12 [00:21<00:57,  7.13s/it]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# 100%|███████████████████████████████████████████| 12/12 [00:32<00:00,  2.68s/it]
# XYZ_24 PA-MPJPE: 52.387371 | MPJPE: 74.675046, x: 26.551470, y: 33.21, z: 49.875733
#
# Test result is saved at exp/test_3d_kpt.json
# PVE: 92.1811563827151
# ...

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_121_145.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug/average_model_121_145.pth...
# loading annotations into memory...
# Done (t=8.23s)
# creating index...
# index created!
# ##### Testing on 3DPW #####
# ...
#   0%|                                                    | 0/12 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 47.675427 | MPJPE: 76.627707, x: 28.748056, y: 33.29, z: 50.509625
#
#  42%|██████████████████▎                         | 5/12 [00:21<00:35,  5.08s/it]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# 100%|███████████████████████████████████████████| 12/12 [00:31<00:00,  2.63s/it]
# XYZ_24 PA-MPJPE: 52.387371 | MPJPE: 74.675046, x: 26.551470, y: 33.21, z: 49.875733
#
# Test result is saved at exp/test_3d_kpt.json
# PVE: 92.1811563827151
# ...

# %%
ls
# Out:
# assets/                  Evaluation.ipynb  README.md
# AverageCheckpoint.ipynb  examples/         scripts/
# colab.sh                 exp/              setup.py
# configs/                 fetch_data.sh     tensorboard/
# data/                    hybrik/           train_smpl.py
# DebugTest.ipynb          LICENSE           validate_smpl.py
# DownloadDeepPose.ipynb   model_files/

# %% [markdown]
# ## This is 6-block transformer based case from c4130

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.1_inv_sqrt_lr0.0005/model_123.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.1_inv_sqrt_lr0.0005/model_123.pth...
# loading annotations into memory...
# Done (t=8.34s)
# creating index...
# index created!
# ...
#   0%|                                                   | 0/101 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 47.328765 | MPJPE: 77.791896, x: 29.377979, y: 32.79, z: 51.870515
#
# Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# XYZ_24 PA-MPJPE: 52.273171 | MPJPE: 75.821038, x: 26.941028, y: 32.76, z: 51.410359
#
# ...
#   7%|██▉                                        | 7/101 [00:43<08:19,  5.32s/it]PVE: 92.72528798888914
# ##### gt 3dpw err: {'MPJPE': 77.79189573125704, 'PA-MPJPE': 47.328765473835624} #####
# ##### Testing on Human3.6M #####
# ...
# 100%|█████████████████████████████████████████| 101/101 [02:17<00:00,  1.36s/it]
# Evaluation start...
# ...

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.1_inv_sqrt_lr0.0005/average_model_123_127.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.1_inv_sqrt_lr0.0005/average_model_123_127.pth...
# loading annotations into memory...
# Done (t=8.55s)
# creating index...
# index created!
# ##### Testing on 3DHP #####
# ...
#   0%|                                                   | 0/101 [00:00<?, ?it/s]Evaluation start...
# PA MPJPE >> tot: 65.081523; MPJPE >> tot: 89.431842, x: 32.130035, y: 43.68, z: 55.693744
# ##########MPJPE per sequence
# TS1	0.00	25.01	96.29	106.75	24.92	121.58	124.75	38.44	62.64	64.70	155.13	67.18	86.93	81.80	64.54	85.47	98.46	76.74
# TS2	0.00	34.26	115.23	114.93	34.18	116.95	123.21	50.83	86.41	89.54	165.66	88.78	113.21	114.83	97.33	141.73	159.31	96.85
# TS3	0.00	32.95	114.96	136.55	32.72	124.31	156.93	38.07	58.59	66.84	120.22	63.52	108.40	129.35	62.48	114.12	160.65	89.45
# ...

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.1_inv_sqrt_lr0.0005/average_model_121_143.pth
# Out:
# tcp://172.17.0.2:23456, ws:2, rank:0
# tcp://172.17.0.2:23456, ws:2, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.1_inv_sqrt_lr0.0005/average_model_121_143.pth...
# loading annotations into memory...
# Done (t=8.21s)
# creating index...
# index created!
# ##### Testing on 3DPW #####
# ...
#   0%|                                                    | 0/12 [00:00<?, ?it/s]Evaluation start...
# XYZ_14 PA-MPJPE: 46.903123 | MPJPE: 76.819645, x: 28.744794, y: 32.71, z: 51.281615
#
#  42%|██████████████████▎                         | 5/12 [00:22<00:36,  5.16s/it]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# 100%|███████████████████████████████████████████| 12/12 [00:28<00:00,  2.36s/it]
# XYZ_24 PA-MPJPE: 51.803779 | MPJPE: 75.135966, x: 26.434913, y: 32.71, z: 50.999083
#
# Test result is saved at exp/test_3d_kpt.json
# PVE: 91.88307451901676
# ...

# %% [markdown]
# ## This is C4130 custom transformer trained with PW3D

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24_w_pw3d.yaml \
    ./exp/mix_smpl_w_pw3d/hybrik_transformer_smpl24_w_pw3d.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug_w_pw3d/average_model_resnet_181_199.pth
# Out:
# tcp://172.17.0.2:23456, ws:4, rank:0
# tcp://172.17.0.2:23456, ws:4, rank:3
# tcp://172.17.0.2:23456, ws:4, rank:1
# tcp://172.17.0.2:23456, ws:4, rank:2
# Loading model from ./exp/mix_smpl_w_pw3d/hybrik_transformer_smpl24_w_pw3d.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug_w_pw3d/average_model_resnet_181_199.pth...
# loading annotations into memory...
# Done (t=9.08s)
# creating index...
# index created!
# ...
#  17%|███████▋                                    | 4/23 [00:15<01:35,  5.05s/it]XYZ_14 PA-MPJPE: 45.969473 | MPJPE: 74.864908, x: 27.680698, y: 29.81, z: 52.018434
#
#  61%|██████████████████████████▏                | 14/23 [00:21<00:05,  1.50it/s]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# ...
# 100%|███████████████████████████████████████████| 23/23 [00:27<00:00,  1.19s/it]
# XYZ_24 PA-MPJPE: 50.309162 | MPJPE: 73.440896, x: 25.751966, y: 30.54, z: 51.203310
#
# Test result is saved at exp/test_3d_kpt.json
# PVE: 88.05218598932672
# ...
