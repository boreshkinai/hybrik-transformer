# %% [markdown]
# ## HRNET-48 without PW3D, batch size 56x4

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24_hrnet.yaml \
    ./exp/mix_smpl/hybrik_transformer_smpl24_hrnet.yaml-hybrik_transformer_warmup_4000_hrnet_bs56_lr0.0005/average_model_hrnet_181_199.pth \
    12390
# Out:
# tcp://172.17.0.2:12390, ws:4, rank:2
# tcp://172.17.0.2:12390, ws:4, rank:0
# tcp://172.17.0.2:12390, ws:4, rank:3
# tcp://172.17.0.2:12390, ws:4, rank:1
# Loading model from ./exp/mix_smpl/hybrik_transformer_smpl24_hrnet.yaml-hybrik_transformer_warmup_4000_hrnet_bs56_lr0.0005/average_model_hrnet_181_199.pth...
# loading annotations into memory...
# Done (t=9.46s)
# creating index...
# index created!
# ...
#   9%|███▊                                        | 2/23 [00:17<04:14, 12.10s/it]XYZ_14 PA-MPJPE: 43.428351 | MPJPE: 73.569082, x: 26.666231, y: 31.95, z: 48.931699
#
#  39%|█████████████████▏                          | 9/23 [00:25<00:27,  1.94s/it]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# 100%|███████████████████████████████████████████| 23/23 [00:36<00:00,  1.59s/it]
# XYZ_24 PA-MPJPE: 47.723683 | MPJPE: 71.958901, x: 24.667507, y: 32.15, z: 48.331702
#
# ...
# 100%|███████████████████████████████████████████| 23/23 [00:39<00:00,  1.71s/it]
# ...

# %% [markdown]
# ## HRNET-48 with PW3D, batch size 56x4, lr 0.000325

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24_hrnet_w_pw3d.yaml \
    ./exp/mix_smpl_w_pw3d/hybrik_transformer_smpl24_hrnet_w_pw3d.yaml-hybrik_transformer_warmup_4000_hrnet_bs56_lr0.000325_w_pw3d/average_model_hrnet_181_199.pth \
    12390
# Out:
# tcp://172.17.0.2:12390, ws:4, rank:0
# tcp://172.17.0.2:12390, ws:4, rank:2
# tcp://172.17.0.2:12390, ws:4, rank:3
# tcp://172.17.0.2:12390, ws:4, rank:1
# Loading model from ./exp/mix_smpl_w_pw3d/hybrik_transformer_smpl24_hrnet_w_pw3d.yaml-hybrik_transformer_warmup_4000_hrnet_bs56_lr0.000325_w_pw3d/average_model_hrnet_181_199.pth...
# loading annotations into memory...
# Done (t=9.15s)
# creating index...
# index created!
# ...
#   9%|███▊                                        | 2/23 [00:17<04:13, 12.09s/it]XYZ_14 PA-MPJPE: 42.493414 | MPJPE: 72.058235, x: 25.861748, y: 28.76, z: 50.387425
#
#  43%|██████████████████▋                        | 10/23 [00:24<00:20,  1.59s/it]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# 100%|███████████████████████████████████████████| 23/23 [00:36<00:00,  1.59s/it]
# XYZ_24 PA-MPJPE: 45.900028 | MPJPE: 69.969029, x: 24.131626, y: 29.04, z: 48.871837
#
# ...
# 100%|███████████████████████████████████████████| 23/23 [00:38<00:00,  1.67s/it]
# ...

# %% [markdown]
# ## ResNet-34 trained with PW3D

# %%
# !./scripts/validate_smpl.sh \
    ./configs/hybrik_transformer_smpl24_w_pw3d.yaml \
    ./exp/mix_smpl_w_pw3d/hybrik_transformer_smpl24_w_pw3d.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug_w_pw3d/average_model_resnet_181_199.pth
# Out:
# tcp://172.17.0.2:23456, ws:4, rank:0
# tcp://172.17.0.2:23456, ws:4, rank:3
# tcp://172.17.0.2:23456, ws:4, rank:1
# tcp://172.17.0.2:23456, ws:4, rank:2
# Loading model from ./exp/mix_smpl_w_pw3d/hybrik_transformer_smpl24_w_pw3d.yaml-hybrik_transformer_blocks6_layers3_lw512_dp0.0_inv_sqrt_lr0.0005_aug_w_pw3d/average_model_resnet_181_199.pth...
# loading annotations into memory...
# Done (t=9.08s)
# creating index...
# index created!
# ...
#  17%|███████▋                                    | 4/23 [00:15<01:35,  5.05s/it]XYZ_14 PA-MPJPE: 45.969473 | MPJPE: 74.864908, x: 27.680698, y: 29.81, z: 52.018434
#
#  61%|██████████████████████████▏                | 14/23 [00:21<00:05,  1.50it/s]Test result is saved at exp/test_3d_kpt.json
# Evaluation start...
# ...
# 100%|███████████████████████████████████████████| 23/23 [00:27<00:00,  1.19s/it]
# XYZ_24 PA-MPJPE: 50.309162 | MPJPE: 73.440896, x: 25.751966, y: 30.54, z: 51.203310
#
# Test result is saved at exp/test_3d_kpt.json
# PVE: 88.05218598932672
# ...
